# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
data = pd.read_excel("tubes.xlsx")
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\asusm\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\compat\_optional.py:141, in import_optional_dependency(name, extra, errors, min_version)
#     140 try:
# --> 141     module = importlib.import_module(name)
#     142 except ImportError:
#
# File c:\Users\asusm\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1142, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
miskin = data[data["Actual Class"]== "Miskin"]
miskin
# Out:
#     Id  Umur       Status     Pendidikan  Tanggungan    Pekerjaan Penghasilan  \
# 1    2  Muda  Belum Kawin             SD           0  Buruh Lepas      Rendah
# 3    4   Tua        Kawin           SLTP           4       Petani      Rendah
# 5    6  Muda        Kawin             SD           3       Petani      Rendah
# 6    7  Muda        Kawin  Tidak Sekolah           2       Petani      Sedang
# 7    8   Tua        Kawin           SLTP           3  Buruh Lepas      Rendah
# 8    9   Tua        Cerai           SLTA           2        Tiada       Tiada
# 9   10  Muda        Kawin             SD           3       Petani      Rendah
# 12  13   Tua        Kawin             SD           1        Tiada       Tiada
# 13  14  Muda        Kawin             SD           3  Buruh Lepas      Rendah
# 14  15  Muda        Kawin             SD           5       Petani      Sedang
# 15  16   Tua        Kawin             SD           3       Petani      Rendah
# ...

# %%
tidakMiskin = data[data["Actual Class"]== "Tidak Miskin"]
tidakMiskin
# Out:
#     Id  Umur       Status Pendidikan  Tanggungan        Pekerjaan Penghasilan  \
# 0    1   Tua        Kawin       SLTP           1         Pedagang      Tinggi
# 2    3   Tua        Kawin    Sarjana           3  Aparatur Negara      Tinggi
# 4    5  Muda        Kawin    Sarjana           4  Aparatur Negara      Tinggi
# 10  11  Muda        Kawin       SLTP           3           Petani      Sedang
# 11  12  Muda  Belum Kawin         SD           0      Buruh Lepas      Rendah
#
#     Actual Class
# 0   Tidak Miskin
# 2   Tidak Miskin
# 4   Tidak Miskin
# 10  Tidak Miskin
# 11  Tidak Miskin

# %%
tua = data[data["Umur"] == "Tua"]
tua
# Out:
#     Id Umur Status Pendidikan  Tanggungan        Pekerjaan Penghasilan  \
# 0    1  Tua  Kawin       SLTP           1         Pedagang      Tinggi
# 2    3  Tua  Kawin    Sarjana           3  Aparatur Negara      Tinggi
# 3    4  Tua  Kawin       SLTP           4           Petani      Rendah
# 7    8  Tua  Kawin       SLTP           3      Buruh Lepas      Rendah
# 8    9  Tua  Cerai       SLTA           2            Tiada       Tiada
# 12  13  Tua  Kawin         SD           1            Tiada       Tiada
# 15  16  Tua  Kawin         SD           3           Petani      Rendah
# 16  17  Tua  Cerai       SLTA           1            Tiada       Tiada
# 17  18  Tua  Cerai         SD           2            Tiada       Tiada
# 18  19  Tua  Kawin         SD           3      Buruh Lepas      Rendah
#
#     Actual Class
# 0   Tidak Miskin
# 2   Tidak Miskin
# 3         Miskin
# 7         Miskin
# 8         Miskin
# 12        Miskin
# 15        Miskin
# 16        Miskin
# 17        Miskin
# ...

# %%
muda = data[data["Umur"] == "Muda"]
muda
# Out:
#     Id  Umur       Status     Pendidikan  Tanggungan        Pekerjaan  \
# 1    2  Muda  Belum Kawin             SD           0      Buruh Lepas
# 4    5  Muda        Kawin        Sarjana           4  Aparatur Negara
# 5    6  Muda        Kawin             SD           3           Petani
# 6    7  Muda        Kawin  Tidak Sekolah           2           Petani
# 9   10  Muda        Kawin             SD           3           Petani
# 10  11  Muda        Kawin           SLTP           3           Petani
# 11  12  Muda  Belum Kawin             SD           0      Buruh Lepas
# 13  14  Muda        Kawin             SD           3      Buruh Lepas
# 14  15  Muda        Kawin             SD           5           Petani
#
#    Penghasilan  Actual Class
# 1       Rendah        Miskin
# 4       Tinggi  Tidak Miskin
# 5       Rendah        Miskin
# 6       Sedang        Miskin
# 9       Rendah        Miskin
# 10      Sedang  Tidak Miskin
# 11      Rendah  Tidak Miskin
# ...

# %%
kawin = data[data["Status"] == "Kawin"]
kawin
# Out:
#     Id  Umur Status     Pendidikan  Tanggungan        Pekerjaan Penghasilan  \
# 0    1   Tua  Kawin           SLTP           1         Pedagang      Tinggi
# 2    3   Tua  Kawin        Sarjana           3  Aparatur Negara      Tinggi
# 3    4   Tua  Kawin           SLTP           4           Petani      Rendah
# 4    5  Muda  Kawin        Sarjana           4  Aparatur Negara      Tinggi
# 5    6  Muda  Kawin             SD           3           Petani      Rendah
# 6    7  Muda  Kawin  Tidak Sekolah           2           Petani      Sedang
# 7    8   Tua  Kawin           SLTP           3      Buruh Lepas      Rendah
# 9   10  Muda  Kawin             SD           3           Petani      Rendah
# 10  11  Muda  Kawin           SLTP           3           Petani      Sedang
# 12  13   Tua  Kawin             SD           1            Tiada       Tiada
# 13  14  Muda  Kawin             SD           3      Buruh Lepas      Rendah
# ...

# %%
belumkawin = data[data["Status"] == "Belum Kawin"]
belumkawin
# Out:
#     Id  Umur       Status Pendidikan  Tanggungan    Pekerjaan Penghasilan  \
# 1    2  Muda  Belum Kawin         SD           0  Buruh Lepas      Rendah
# 11  12  Muda  Belum Kawin         SD           0  Buruh Lepas      Rendah
#
#     Actual Class
# 1         Miskin
# 11  Tidak Miskin

# %%
cerai = data[data["Status"] == "Cerai"]
cerai
# Out:
#     Id Umur Status Pendidikan  Tanggungan Pekerjaan Penghasilan Actual Class
# 8    9  Tua  Cerai       SLTA           2     Tiada       Tiada       Miskin
# 16  17  Tua  Cerai       SLTA           1     Tiada       Tiada       Miskin
# 17  18  Tua  Cerai         SD           2     Tiada       Tiada       Miskin

# %%
sd = data[data["Pendidikan"] == "SD"]
sd
# Out:
#     Id  Umur       Status Pendidikan  Tanggungan    Pekerjaan Penghasilan  \
# 1    2  Muda  Belum Kawin         SD           0  Buruh Lepas      Rendah
# 5    6  Muda        Kawin         SD           3       Petani      Rendah
# 9   10  Muda        Kawin         SD           3       Petani      Rendah
# 11  12  Muda  Belum Kawin         SD           0  Buruh Lepas      Rendah
# 12  13   Tua        Kawin         SD           1        Tiada       Tiada
# 13  14  Muda        Kawin         SD           3  Buruh Lepas      Rendah
# 14  15  Muda        Kawin         SD           5       Petani      Sedang
# 15  16   Tua        Kawin         SD           3       Petani      Rendah
# 17  18   Tua        Cerai         SD           2        Tiada       Tiada
# 18  19   Tua        Kawin         SD           3  Buruh Lepas      Rendah
#
#     Actual Class
# 1         Miskin
# 5         Miskin
# 9         Miskin
# 11  Tidak Miskin
# 12        Miskin
# 13        Miskin
# 14        Miskin
# ...

# %%
sltp = data[data["Pendidikan"] == "SLTP"]
sltp
# Out:
#     Id  Umur Status Pendidikan  Tanggungan    Pekerjaan Penghasilan  \
# 0    1   Tua  Kawin       SLTP           1     Pedagang      Tinggi
# 3    4   Tua  Kawin       SLTP           4       Petani      Rendah
# 7    8   Tua  Kawin       SLTP           3  Buruh Lepas      Rendah
# 10  11  Muda  Kawin       SLTP           3       Petani      Sedang
#
#     Actual Class
# 0   Tidak Miskin
# 3         Miskin
# 7         Miskin
# 10  Tidak Miskin

# %%
slta = data[data["Pendidikan"] == "SLTA"]
slta
# Out:
#     Id Umur Status Pendidikan  Tanggungan Pekerjaan Penghasilan Actual Class
# 8    9  Tua  Cerai       SLTA           2     Tiada       Tiada       Miskin
# 16  17  Tua  Cerai       SLTA           1     Tiada       Tiada       Miskin

# %%
sarjana = data[data["Pendidikan"] == "Sarjana"]
sarjana
# Out:
#    Id  Umur Status Pendidikan  Tanggungan        Pekerjaan Penghasilan  \
# 2   3   Tua  Kawin    Sarjana           3  Aparatur Negara      Tinggi
# 4   5  Muda  Kawin    Sarjana           4  Aparatur Negara      Tinggi
#
#    Actual Class
# 2  Tidak Miskin
# 4  Tidak Miskin

# %%
tanggungan = data[data["Tanggungan"] == 0]
tanggungan
# Out:
#     Id  Umur       Status Pendidikan  Tanggungan    Pekerjaan Penghasilan  \
# 1    2  Muda  Belum Kawin         SD           0  Buruh Lepas      Rendah
# 11  12  Muda  Belum Kawin         SD           0  Buruh Lepas      Rendah
#
#     Actual Class
# 1         Miskin
# 11  Tidak Miskin

# %%
tanggungan1 = data[data["Tanggungan"] == 1]
tanggungan1
# Out:
#     Id Umur Status Pendidikan  Tanggungan Pekerjaan Penghasilan  Actual Class
# 0    1  Tua  Kawin       SLTP           1  Pedagang      Tinggi  Tidak Miskin
# 12  13  Tua  Kawin         SD           1     Tiada       Tiada        Miskin
# 16  17  Tua  Cerai       SLTA           1     Tiada       Tiada        Miskin

# %%
tanggungan2 = data[data["Tanggungan"] == 2]
tanggungan2
# Out:
#     Id  Umur Status     Pendidikan  Tanggungan Pekerjaan Penghasilan  \
# 6    7  Muda  Kawin  Tidak Sekolah           2    Petani      Sedang
# 8    9   Tua  Cerai           SLTA           2     Tiada       Tiada
# 17  18   Tua  Cerai             SD           2     Tiada       Tiada
#
#    Actual Class
# 6        Miskin
# 8        Miskin
# 17       Miskin

# %%
tanggungan3 = data[data["Tanggungan"] == 3]
tanggungan3
# Out:
#     Id  Umur Status Pendidikan  Tanggungan        Pekerjaan Penghasilan  \
# 2    3   Tua  Kawin    Sarjana           3  Aparatur Negara      Tinggi
# 5    6  Muda  Kawin         SD           3           Petani      Rendah
# 7    8   Tua  Kawin       SLTP           3      Buruh Lepas      Rendah
# 9   10  Muda  Kawin         SD           3           Petani      Rendah
# 10  11  Muda  Kawin       SLTP           3           Petani      Sedang
# 13  14  Muda  Kawin         SD           3      Buruh Lepas      Rendah
# 15  16   Tua  Kawin         SD           3           Petani      Rendah
# 18  19   Tua  Kawin         SD           3      Buruh Lepas      Rendah
#
#     Actual Class
# 2   Tidak Miskin
# 5         Miskin
# 7         Miskin
# 9         Miskin
# 10  Tidak Miskin
# 13        Miskin
# 15        Miskin
# 18        Miskin

# %%
tanggungan4 = data[data["Tanggungan"] == 4]
tanggungan4
# Out:
#    Id  Umur Status Pendidikan  Tanggungan        Pekerjaan Penghasilan  \
# 3   4   Tua  Kawin       SLTP           4           Petani      Rendah
# 4   5  Muda  Kawin    Sarjana           4  Aparatur Negara      Tinggi
#
#    Actual Class
# 3        Miskin
# 4  Tidak Miskin

# %%
tanggungan5 = data[data["Tanggungan"] == 5]
tanggungan5
# Out:
#     Id  Umur Status Pendidikan  Tanggungan Pekerjaan Penghasilan Actual Class
# 14  15  Muda  Kawin         SD           5    Petani      Sedang       Miskin

# %%
petani = data[data["Pekerjaan"] == "Petani"]
petani
# Out:
#     Id  Umur Status     Pendidikan  Tanggungan Pekerjaan Penghasilan  \
# 3    4   Tua  Kawin           SLTP           4    Petani      Rendah
# 5    6  Muda  Kawin             SD           3    Petani      Rendah
# 6    7  Muda  Kawin  Tidak Sekolah           2    Petani      Sedang
# 9   10  Muda  Kawin             SD           3    Petani      Rendah
# 10  11  Muda  Kawin           SLTP           3    Petani      Sedang
# 14  15  Muda  Kawin             SD           5    Petani      Sedang
# 15  16   Tua  Kawin             SD           3    Petani      Rendah
#
#     Actual Class
# 3         Miskin
# 5         Miskin
# 6         Miskin
# 9         Miskin
# 10  Tidak Miskin
# 14        Miskin
# 15        Miskin

# %%
aparaturNegara = data[data["Pekerjaan"] == "Aparatur Negara"]
aparaturNegara
# Out:
#    Id  Umur Status Pendidikan  Tanggungan        Pekerjaan Penghasilan  \
# 2   3   Tua  Kawin    Sarjana           3  Aparatur Negara      Tinggi
# 4   5  Muda  Kawin    Sarjana           4  Aparatur Negara      Tinggi
#
#    Actual Class
# 2  Tidak Miskin
# 4  Tidak Miskin

# %%
buruhLepas = data[data["Pekerjaan"] == "Buruh Lepas"]
buruhLepas
# Out:
#     Id  Umur       Status Pendidikan  Tanggungan    Pekerjaan Penghasilan  \
# 1    2  Muda  Belum Kawin         SD           0  Buruh Lepas      Rendah
# 7    8   Tua        Kawin       SLTP           3  Buruh Lepas      Rendah
# 11  12  Muda  Belum Kawin         SD           0  Buruh Lepas      Rendah
# 13  14  Muda        Kawin         SD           3  Buruh Lepas      Rendah
# 18  19   Tua        Kawin         SD           3  Buruh Lepas      Rendah
#
#     Actual Class
# 1         Miskin
# 7         Miskin
# 11  Tidak Miskin
# 13        Miskin
# 18        Miskin

# %%
pedagang = data[data["Pekerjaan"] == "Pedagang"]
pedagang
# Out:
#    Id Umur Status Pendidikan  Tanggungan Pekerjaan Penghasilan  Actual Class
# 0   1  Tua  Kawin       SLTP           1  Pedagang      Tinggi  Tidak Miskin

# %%
tiada = data[data["Pekerjaan"] == "Tiada"]
tiada
# Out:
#     Id Umur Status Pendidikan  Tanggungan Pekerjaan Penghasilan Actual Class
# 8    9  Tua  Cerai       SLTA           2     Tiada       Tiada       Miskin
# 12  13  Tua  Kawin         SD           1     Tiada       Tiada       Miskin
# 16  17  Tua  Cerai       SLTA           1     Tiada       Tiada       Miskin
# 17  18  Tua  Cerai         SD           2     Tiada       Tiada       Miskin

# %%
tinggi = data[data["Penghasilan"] == "Tinggi"]
tinggi
# Out:
#    Id  Umur Status Pendidikan  Tanggungan        Pekerjaan Penghasilan  \
# 0   1   Tua  Kawin       SLTP           1         Pedagang      Tinggi
# 2   3   Tua  Kawin    Sarjana           3  Aparatur Negara      Tinggi
# 4   5  Muda  Kawin    Sarjana           4  Aparatur Negara      Tinggi
#
#    Actual Class
# 0  Tidak Miskin
# 2  Tidak Miskin
# 4  Tidak Miskin

# %%
Sedang = data[data["Penghasilan"] == "Sedang"]
Sedang
# Out:
#     Id  Umur Status     Pendidikan  Tanggungan Pekerjaan Penghasilan  \
# 6    7  Muda  Kawin  Tidak Sekolah           2    Petani      Sedang
# 10  11  Muda  Kawin           SLTP           3    Petani      Sedang
# 14  15  Muda  Kawin             SD           5    Petani      Sedang
#
#     Actual Class
# 6         Miskin
# 10  Tidak Miskin
# 14        Miskin

# %%
rendah = data[data["Penghasilan"] == "Rendah"]
rendah
# Out:
#     Id  Umur       Status Pendidikan  Tanggungan    Pekerjaan Penghasilan  \
# 1    2  Muda  Belum Kawin         SD           0  Buruh Lepas      Rendah
# 3    4   Tua        Kawin       SLTP           4       Petani      Rendah
# 5    6  Muda        Kawin         SD           3       Petani      Rendah
# 7    8   Tua        Kawin       SLTP           3  Buruh Lepas      Rendah
# 9   10  Muda        Kawin         SD           3       Petani      Rendah
# 11  12  Muda  Belum Kawin         SD           0  Buruh Lepas      Rendah
# 13  14  Muda        Kawin         SD           3  Buruh Lepas      Rendah
# 15  16   Tua        Kawin         SD           3       Petani      Rendah
# 18  19   Tua        Kawin         SD           3  Buruh Lepas      Rendah
#
#     Actual Class
# 1         Miskin
# 3         Miskin
# 5         Miskin
# 7         Miskin
# 9         Miskin
# 11  Tidak Miskin
# 13        Miskin
# 15        Miskin
# 18        Miskin

# %%
ptiada = data[data["Penghasilan"] == "Tiada"]
ptiada
# Out:
#     Id Umur Status Pendidikan  Tanggungan Pekerjaan Penghasilan Actual Class
# 8    9  Tua  Cerai       SLTA           2     Tiada       Tiada       Miskin
# 12  13  Tua  Kawin         SD           1     Tiada       Tiada       Miskin
# 16  17  Tua  Cerai       SLTA           1     Tiada       Tiada       Miskin
# 17  18  Tua  Cerai         SD           2     Tiada       Tiada       Miskin

# %%
actualclass = data.groupby("Actual Class")["Actual Class"].count()
pd.DataFrame(actualclass)
# Out:
#               Actual Class
# Actual Class
# Miskin                  14
# Tidak Miskin             5
